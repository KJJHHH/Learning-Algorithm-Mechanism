# %%
# %load_ext autoreload
# %autoreload 2
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import torch, copy
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as Data
import torch.nn.functional as F
import torchvision
import  matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from module.model import TwoLayerNet
from module.Weight_tune import *
from module.Reorg import *
from module.Cram import *
from module.init import *
from module.lts import *
from module.utils import *
from module.data import *
import datetime

# %% [markdown]
# # New Learning mechanism

# %% [markdown]
# ### Data

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dtype = torch.float64

data = pd.read_csv('Copper_forecasting_data.csv')

sc = StandardScaler()
X = data.drop(["y"], axis = 1)
X = sc.fit_transform(X)
y = data["y"] / 1000

train_size = int(len(X)*0.8)
batch_size = 30

X_train = X[:train_size, :]
y_train = y[:train_size]
X_test = X[train_size:, :]
y_test = y[train_size:] 

X_train = torch.tensor(np.array(X_train), dtype=dtype)
X_test = torch.tensor(np.array(X_test), dtype=dtype)
y_train = torch.tensor(np.array(y_train), dtype=dtype)
y_test = torch.tensor(np.array(y_test), dtype=dtype)
input_dim = X_train.shape[1]
    

test_loader = torch.utils.data.DataLoader(
    MyDataset(X_test.to(device), y_test.to(device)), 
    batch_size = batch_size, 
    shuffle=False, 
    drop_last = False)

# %% [markdown]
# ### Model

# %%
model = TwoLayerNet(input_dim, 1, 1)

# %% [markdown]
# ### Config

# %%
# learning goal: max eps < learning goal
learning_goal = torch.exp(torch.tensor(1)).to(dtype = dtype)
lr_rate = .01
lr_bound = 1e-5
criterion = nn.MSELoss()
epochs = 50
"""
# Note
1. hidden dim should check the previous model. dynamically change
2. For lr_rate, lr bound, lr goal (eps bound) are all the same fro eahc module
"""
config_wt = {
    "epochs": epochs,
    "criterion": criterion,        # loss function
    "lr_rate": lr_rate,            # learning rate 
    "lr_bound": lr_bound,          # lower bound of learning rate 
    "lr_goal": learning_goal,      # if regular eps < eps_reg: accept the model
}

config_cram = {
    "lr_goal": learning_goal, 
    "s": 0.001,                     # a small num in cram
}

config_reorg  = {
    "epochs": epochs,
    "criterion": criterion,        # loss function
    "lr_rate": lr_rate,            # learning rate 
    "lr_bound": lr_bound,          # lower bound of learning rate 
    "lr_goal": learning_goal,      # if regular eps < eps_reg: accept the model
    "print_reg": False,            # print detail, eg. loss for each epoch, or not
    "print_w_tune": False,         # print detail, eg. loss for each epoch, or not
    "validate_run": False,         # validate the model, or not
}
# NOTE 
# 1. for leaning goals, if first using weightune and no LTS or otherthings, 
# 13 for getting acceptable wt | 10 not acceptable

# %% [markdown]
# ### Full Path

# %% [markdown]
# - L11 p9, third learning mechanism

# %%
# check the random of init. Should not be random in init.
k = 0
loss = []
while k<2:
    model = init_model(X_train, y_train)
    # 2. obtaining_LTS / selecting_LTS
    train_loader, indices, n = lts(model, X_train, y_train, learning_goal)

    # 3. check learning goal
    acceptable, model, train_loss_list, test_loss_list = \
        module_weight_EU_LG_UA(model, train_loader, test_loader, **config_wt)
    acceptable, eps, y_pred = check_acceptable(train_loader, model, learning_goal)
    loss.append(train_loss_list)
    k+=1

# %%
# Result file
file_create_time = str(datetime.datetime.now())
file = open(file_create_time + '.txt', 'a')

# %%
#################################################################
# Full step for the learning algorithm mechanism
# NOTE
# 1. model right before reorg always need to be acceptable model
# 2. model after cram and reorg always need to be acceptable 
# 3. check for the above every time after cram and reorg
# 4. the randomness: in cram find r
#################################################################

# 1. initializing_1_ReLU_LR | L11 p2
model = init_model(X_train, y_train)
n = 0
model_history = {}


while n < len(X_train):
    print(f"################################## New lts #######################################")
    models_within_iter = {}
    # 2. obtaining_LTS / selecting_LTS
    train_loader, indices, X_train_lts, y_train_lts, n = lts(model, X_train, y_train, learning_goal)

    # 3. check learning goal
    acceptable, eps_sqaure, y_pred = check_acceptable(train_loader, model, learning_goal)
    models_within_iter["begin"] = model
    if acceptable:
        continue

    else:
        torch.save(model, "unacceptable/selecting.pth")

        # store model in acceptable/wt.pth if acceptable
        # store model in unacceptable/wt.pth if not acceptable
        acceptable, model, train_loss_list, test_loss_list = \
            module_weight_EU_LG_UA(model, train_loader, test_loader, **config_wt)
        models_within_iter["wt"] = model
        
        if acceptable:
            print("////////// Start REORG with accpetable wt //////////")   
            print(f"model after wt: {model}")

            # load model in acceptable/wt.pth if wt acceptable
            # NOTE: the loaded model in reorg module is the same with "model" now
            pre_module = "wt"
            reorg = reorganising(pre_module, train_loader, test_loader, **config_reorg)
            reorg.reorganising()
            model = reorg.model
            models_within_iter["reorg"] = model
            print(f"model after reorg: {model}")

        else:
            print("////////// Start CRAM and REORG with unacceptable wt //////////")

            # restore model after wt, unacceptable
            model = torch.load("unacceptable/selecting.pth")    
            acceptable, eps_square, y_pred = check_acceptable(train_loader, model, learning_goal)
            print(f"model after wt: {model}")
            print(f"eps_square (last 10) before cram: {eps_square[-10:]}")

            # load model in unacceptable/wt.pth if wt not acceptable       
            # store acceptable cram in acceptable/cram.pth 
            cram = cramming(model, X_train[indices], y_train[indices], **config_cram)            
            cram.cram() 
            model = cram.model
            models_within_iter["cram"] = model
            print(f"model after cram: {model}")            

            # check accetable
            acceptable, eps_square, y_pred = check_acceptable(train_loader, model, learning_goal)
            print(f"eps_sqaure (last 10) after cram: {eps_square[-10:]}")

            if not acceptable:
                print("weird cram")
                break

            # load model in acceptable/cram.pth if cram acceptable
            # store acceptable cram in acceptable/cram.pth
            pre_module = "cram"
            reorg = reorganising(pre_module, train_loader, test_loader, **config_reorg)
            reorg.reorganising()
            model = reorg.model
            models_within_iter["reorg"] = model
            print(f"model after reorg: {model}")

            # check 
            acceptable, eps_square, y_pred = check_acceptable(train_loader, model, learning_goal)
            if acceptable:
                pass
            else:
                print("weird reorg")
                break
            
    model_history[n] = models_within_iter
# Out:
# ################################## New lts #######################################
# Total obtaining n: 328
# obtaining n over lr goal: 0
# Total select n: 329
# select n over lr goal: 1
# Save model and lr increase9156 ---------
# c:\Users\USER\anaconda3\envs\learningalgo\lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([30])) that is different to the input size (torch.Size([30, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\USER\anaconda3\envs\learningalgo\lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([5])) that is different to the input size (torch.Size([5, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# lr too small1.60525109870369683 ---------
# non acceptable module at max eps tensor([11.0633], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=1, bias=True)
#   (layer_out): Linear(in_features=1, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [7.5201]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 328th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [4.0895e-23]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 25.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 50.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 75.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# model after reorg: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )
# ################################## New lts #######################################
# Total obtaining n: 329
# obtaining n over lr goal: 0
# Total select n: 330
# select n over lr goal: 1
# non acceptable module at max eps tensor([40318.7546], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [7.6099]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 329th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [2.3338e-24]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 14.29%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 28.57%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 42.86%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([192.9744], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 57.14%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 71.43%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([175.0620], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 85.71%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# model after reorg: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
# ################################## New lts #######################################
# Total obtaining n: 330
# obtaining n over lr goal: 0
# Total select n: 331
# select n over lr goal: 1
# lr too small218414.256205663841 ---------
# non acceptable module at max eps tensor([2175489.0026], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=7, bias=True)
#   (layer_out): Linear(in_features=7, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [7.6148]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 330th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [3.7517e-22]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 10.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 20.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 30.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 40.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 50.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 60.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([211.5036], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 70.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 80.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 90.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# model after reorg: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
# ################################## New lts #######################################
# Total obtaining n: 331
# obtaining n over lr goal: 0
# Total select n: 332
# select n over lr goal: 1
# lr too small267226.877219009835 ---------
# non acceptable module at max eps tensor([3395578.0576], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=10, bias=True)
#   (layer_out): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [7.6643]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 331th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [8.5323e-25]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 7.69%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 15.38%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 23.08%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 30.77%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 38.46%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 46.15%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 53.85%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 61.54%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 69.23%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 76.92%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 84.62%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 92.31%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# model after reorg: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
# ################################## New lts #######################################
# Total obtaining n: 332
# obtaining n over lr goal: 0
# Total select n: 333
# select n over lr goal: 1
# lr too small389138.951790535655 ---------
# non acceptable module at max eps tensor([2528003.4053], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=13, bias=True)
#   (layer_out): Linear(in_features=13, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [7.6824]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 332th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [2.3555e-24]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 6.25%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 12.50%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 18.75%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 25.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 31.25%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 37.50%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 43.75%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([27.1296], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 50.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([20.5886], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 56.25%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([22.1121], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 62.50%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 68.75%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 75.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 81.25%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 87.50%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 93.75%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# model after reorg: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
# ################################## New lts #######################################
# Total obtaining n: 333
# obtaining n over lr goal: 0
# Total select n: 334
# select n over lr goal: 1
# lr too small428260.501021695562 ---------
# non acceptable module at max eps tensor([11022401.1459], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=16, bias=True)
#   (layer_out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [7.7630]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 333th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [2.6245e-23]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 5.26%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 10.53%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 15.79%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([25.4738], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 21.05%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 26.32%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 31.58%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 36.84%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 42.11%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([24.6361], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 47.37%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([22.2835], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 52.63%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 57.89%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([22.0686], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 63.16%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 68.42%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 73.68%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 78.95%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([31.4517], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 84.21%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([26.3999], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 89.47%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 94.74%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# model after reorg: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
# ################################## New lts #######################################
# Total obtaining n: 334
# obtaining n over lr goal: 0
# Total select n: 335
# select n over lr goal: 1
# lr too small1278991.41876346049 ---------
# non acceptable module at max eps tensor([12186604.7855], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=19, bias=True)
#   (layer_out): Linear(in_features=19, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [7.7757]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 334th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [1.6908e-22]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 4.55%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 9.09%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 13.64%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 18.18%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([25.0355], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 22.73%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 27.27%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([24.8783], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 31.82%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 36.36%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 40.91%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([27.3155], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 45.45%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 50.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 54.55%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 59.09%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 63.64%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 68.18%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 72.73%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 77.27%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 81.82%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 86.36%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 90.91%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 95.45%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# model after reorg: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
# ################################## New lts #######################################
# Total obtaining n: 335
# obtaining n over lr goal: 0
# Total select n: 336
# select n over lr goal: 1
# non acceptable module at max eps tensor([11966604.7296], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# ////////// Start CRAM and REORG with unacceptable wt //////////
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=22, bias=True)
#   (layer_out): Linear(in_features=22, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_square (last 10) before cram: tensor([[6.5449],
#         [6.6698],
#         [6.8589],
#         [6.9040],
#         [6.9042],
#         [7.2052],
#         [7.2850],
#         [7.3423],
#         [7.3837],
#         [8.0658]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# cramming sample 335th |0.00% total of 1
# model after cram: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
# eps_sqaure (last 10) after cram: tensor([[6.5449e+00],
#         [6.6698e+00],
#         [6.8589e+00],
#         [6.9040e+00],
#         [6.9042e+00],
#         [7.2052e+00],
#         [7.2850e+00],
#         [7.3423e+00],
#         [7.3837e+00],
#         [6.7701e-23]], dtype=torch.float64, grad_fn=<SliceBackward0>)
# Acceptable SLFN exist in 'acceptable/cram.pth'.
# =================== reorganising ===================
# [ 0.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 4.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 8.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([20.8260], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 12.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 16.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 20.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 24.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 28.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 32.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 36.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 40.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 44.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 48.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=25, bias=True)
# ...
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 7.27%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 9.09%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 10.91%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 12.73%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 14.55%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([36.0116], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 16.36%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([37.5996], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 18.18%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 20.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([32.5343], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 21.82%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([34.6803], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 23.64%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 25.45%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 27.27%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([36.6795], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 29.09%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 30.91%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 32.73%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 34.55%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 36.36%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 38.18%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 40.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 41.82%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 43.64%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 45.45%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([33.4710], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 47.27%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 49.09%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 50.91%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 52.73%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 54.55%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 56.36%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 58.18%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 60.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 61.82%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 63.64%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 65.45%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 67.27%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 69.09%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([34.3367], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 70.91%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 72.73%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 74.55%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 76.36%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 78.18%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# non acceptable module at max eps tensor([32.7977], dtype=torch.float64, grad_fn=<UnbindBackward0>)
# [ 80.00%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 81.82%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 83.64%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 85.45%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 87.27%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 89.09%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# [ 90.91%] ------------> Checking nodes...
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=55, bias=True)
#   (layer_out): Linear(in_features=55, out_features=1, bias=True)
#   (relu): ReLU()
# )
#     --> Start regularising_EU_LG_UA
# Try trim model: Copy model and delete nodes success
#     --> Start module_EU_LG
# | 60.00%| Epoch 30

# %%
model = torch.load("unacceptable/selecting.pth")    

target_dtype = torch.float64
for param in model.parameters():
    param.data = param.data.to(dtype=target_dtype)
    if param.grad is not None:
        param.grad.data = param.grad.data.to(dtype=target_dtype)

# %%
X_train
# Out:
# tensor([[ 0.9495,  1.7060,  1.4923,  ..., -1.3061, -0.5316,  1.7838],
#         [ 0.9954,  1.4859,  1.5214,  ..., -1.3392, -0.5316,  1.7838],
#         [ 0.8272,  1.5149,  1.2368,  ..., -1.3392, -0.5316,  1.5801],
#         ...,
#         [-1.0842, -0.0204, -0.1012,  ...,  0.8492,  1.1269, -0.5588],
#         [-1.0383, -0.1033, -0.1423,  ...,  0.8492,  1.0956, -0.5588],
#         [-0.9466, -0.1442, -0.1565,  ...,  0.7829,  0.9078, -0.4569]],
#        dtype=torch.float64)

# %%
from module.Cram import cramming

train_loader, indices, X_train_lts, y_train_lts, n = lts(
                                model, 
                                X_train, 
                                y_train, 
                                learning_goal
                                )

print(f"model after wt: {model}")
acceptable, eps, y_pred = check_acceptable(train_loader, model, learning_goal)
# load model in unacceptable/wt.pth if wt not acceptable       
# store acceptable cram in acceptable/cram.pth 
cram = cramming(model, X_train[indices], y_train[indices], **config_cram)            
cram.cram() 
model = cram.model
# acceptable, eps, y_pred = check_acceptable(train_loader, model, learning_goal)
# acceptable, eps
# Out:
# Total obtaining n: 0
# obtaining n over lr goal: 0
# Total select n: 1
# select n over lr goal: 1
# model after wt: TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=1, bias=True)
#   (layer_out): Linear(in_features=1, out_features=1, bias=True)
#   (relu): ReLU()
# )
# cramming sample 0th |0.00% total of 1
# try vector 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 15
#      12 # load model in unacceptable/wt.pth if wt not acceptable
#      13 # store acceptable cram in acceptable/cram.pth
#      14 cram = cramming(model, X_train[indices], y_train[indices], **config_cram)
# ---> 15 cram.cram()
#      16 model = cram.model
#      17 # acceptable, eps, y_pred = check_acceptable(train_loader, model, learning_goal)
#      18 # acceptable, eps
#
# File c:\Users\USER\Desktop\Copper\module\Cram.py:51, in cramming.cram(self)
#      49 for i, k in enumerate(ks):
#      50     print(f"cramming sample {k.item()}th |{i/len(ks)*100:.2f}% total of {len(ks)}")
# ---> 51     self.cram_find_r(k)
#      52     self.cram_add_node(k)
#      53 torch.save(self.model, "acceptable/Cram.pth")
#
# File c:\Users\USER\Desktop\Copper\module\Cram.py:79, in cramming.cram_find_r(self, k)
#      76 dots = ((X_no_k - self.X_train[k]) @ r.T)
#      78 # (torch.sum(dots == 0) == 0)
# ---> 79 if (torch.sum(dots == 0) == 0) and (max((self.s + dots) * (self.s - dots)) < 0):
#      80     self.r = r
#      81     break
#
# ValueError: max() arg is an empty sequence

# %%
acceptable, eps, y_pred = check_acceptable(train_loader, model, learning_goal)
acceptable
model
# Out:
# TwoLayerNet(
#   (layer_1): Linear(in_features=18, out_features=4, bias=True)
#   (layer_out): Linear(in_features=4, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
model = init_model(X_train, y_train)
train_loader_lts, indices, n = lts(model, X_train, y_train, learning_goal)
acceptable, eps, y_pred = check_acceptable(train_loader_lts, model, learning_goal)
torch.save(model, "unacceptable/selecting_wt.pth")
indices, eps
eps[eps>learning_goal]
# Out:
# Total obtaining n: 64
# obtaining n over lr goal: 0
# Total select n: 65
# select n over lr goal: 1
# tensor([0.3091])

# %%
acceptable, model, train_loss_list, test_loss_list = \
            module_weight_EU_LG_UA(model, train_loader_lts, test_loader, **config_wt)
acceptable, eps, y_pred = check_acceptable(train_loader, model, learning_goal)
eps

# %%
model = torch.load("unacceptable/selecting_wt.pth")  
acceptable, eps, y_pred = check_acceptable(train_loader_lts, model, learning_goal)
eps[eps>learning_goal]
# Out:
# tensor([0.3091])

# %%
from module.Cram import *
config_cram["s"] = .001
model = torch.load("unacceptable/selecting_wt.pth")          
acceptable, eps, y_pred = check_acceptable(train_loader_lts, model, learning_goal)  
print(max(eps))
cram = cramming(
    model, 
    X_train[indices], 
    y_train[indices], 
    **config_cram)
cram.cram()
model = cram.model
acceptable, eps, y_pred = check_acceptable(train_loader_lts, model, learning_goal)  
print(max(eps))
# Out:
# tensor([0.3091])
# cramming sample 64th |0.00% total of 1
# tensor([0.2946])

# %%
relu = nn.ReLU()
for i in range(len(indices)):
    w = relu(torch.dot(x[i]-x[64], cram.r) + cram.s) \
        + relu(torch.dot(x[i]-x[64], cram.r) - cram.s) \
        - 2*relu(torch.dot(x[i]-x[64], cram.r)) 
    print(w)

# %%
a = cram.model.layer_1.weight.data @ x[64].T
a_ = model.layer_1.weight.data @ x[64].T
print(a_, a)
print("\n")
print(cram.model.layer_1.bias.data)
a_ = a_ + model.layer_1.bias.data
a = a.T + cram.model.layer_1.bias.data
print(relu(a_), relu(a))
print("\n")
print(model.layer_out.weight.data, cram.model.layer_out.weight.data)
print(model.layer_out.weight.data @ relu(a_),
      cram.model.layer_out.weight.data @ relu(a))
a_ = model.layer_out.weight.data @ relu(a_) + model.layer_out.bias.data.reshape(1, 1)
a = cram.model.layer_out.weight.data @ relu(a) + cram.model.layer_out.bias.data.reshape(1, 1)
print(model.layer_out.bias.data.reshape(1, 1), cram.model.layer_out.bias.data.reshape(1, 1))
print(a, a_)
# Out:
# tensor([8.3716]) tensor([8.3716, 5.6251, 5.6251, 5.6251])
#
#
# tensor([14.3434, -5.6241, -5.6251, -5.6261])
# tensor([22.7149]) tensor([2.2715e+01, 9.9993e-04, 0.0000e+00, 0.0000e+00])
#
#
# tensor([[1.]]) tensor([[   1.0000,  309.0630, -618.1259,  309.0630]])
# tensor([22.7149]) tensor([23.0240])
# tensor([[34.4350]]) tensor([[0.0373]])
# tensor([[23.0613]]) tensor([[57.1499]])

# %%
model(X_train)
# Out:
# tensor([[21.9945],
#         [59.9945],
#         [47.9945],
#         [23.9945],
#         [59.9945],
#         [75.9945],
#         [53.9945],
#         [57.9945],
#         [53.9945],
#         [31.9945],
#         [55.9945],
#         [51.9945],
#         [65.9945],
#         [47.9945],
#         [39.9945],
#         [39.9945],
#         [ 7.9945],
#         [47.9945],
#         [57.9945],
#         [ 3.9945],
#         [39.9945],
#         [11.9945],
#         [53.9945],
#         [61.9945],
#         [59.9945],
#         [63.9945],
#         [51.9945],
#         [71.9945],
#         [59.9945],
#         [67.9945],
#         [51.9945],
#         [47.9945],
#         [35.9945],
#         [27.9945],
#         [71.9945],
#         [63.9945],
#         [49.9945],
#         [57.9945],
#         [55.9945],
#         [57.9945],
#         [57.9945],
#         [67.9945],
#         [59.9945],
#         [49.9945],
#         [71.9945],
#         [43.9945],
#         [75.9945],
#         [35.9945],
#         [63.9945],
#         [75.9945],
#         [63.9945],
#         [51.9945],
#         [59.9945],
#         [53.9945],
#         [63.9945],
#         [67.9945],
#         [63.9945],
#         [47.9945],
#         [47.9945],
#         [55.9945],
#         [59.9945],
#         [59.9945],
#         [43.9945],
#         [55.9945],
#         [59.9945],
#         [63.9945],
#         [39.9945],
#         [47.9945],
#         [73.9945],
#         [53.9945],
#         [39.9945],
#         [65.9945],
#         [55.9945],
#         [13.9945],
#         [49.9945],
#         [19.9945],
#         [37.9945],
#         [47.9945],
#         [48.9945],
#         [39.9945],
#         [43.9945],
#         [37.9945],
#         [55.9945],
#         [45.9945],
#         [38.9945],
#         [16.9945],
#         [51.9945],
#         [43.9945],
#         [57.9945],
#         [53.9945],
#         [45.9945],
#         [56.9945],
#         [15.9945],
#         [51.9945],
#         [45.9945],
#         [43.9945],
#         [51.9945],
#         [29.9945],
#         [15.9945],
#         [55.9945],
#         [55.9945],
#         [23.9945],
#         [12.9945],
#         [49.9945],
#         [57.9945],
#         [49.9945],
#         [55.9945],
#         [48.9945],
#         [45.9945],
#         [45.9945],
#         [23.9945],
#         [11.9945],
#         [15.9945],
#         [47.9945],
#         [19.9945],
#         [47.9945],
#         [47.9945],
#         [55.9945],
#         [45.9945],
#         [49.9945],
#         [49.9945],
#         [47.9945],
#         [47.9945],
#         [43.9945],
#         [44.9945],
#         [50.9945],
#         [51.9945],
#         [13.9945],
#         [47.9945],
#         [47.9945],
#         [47.9945],
#         [ 7.9945],
#         [51.9945],
#         [59.9945],
#         [51.9945],
#         [37.9945],
#         [41.9945],
#         [ 9.9945],
#         [23.9945],
#         [15.9945],
#         [ 5.9945],
#         [11.9945],
#         [19.9945],
#         [45.9945],
#         [39.9945],
#         [55.9945],
#         [55.9945],
#         [21.9945],
#         [ 9.9945],
#         [59.9945],
#         [59.9945],
#         [55.9945],
#         [41.9945],
#         [47.9945],
#         [43.9945],
#         [15.9945],
#         [45.9945],
#         [43.9945],
#         [47.9945],
#         [ 9.9945],
#         [45.9945],
#         [37.9945],
#         [39.9945],
#         [45.9945],
#         [39.9945],
#         [ 5.9945],
#         [40.9945],
#         [43.9945],
#         [41.9945],
#         [41.9945],
#         [42.9945],
#         [42.9945],
#         [43.9945],
#         [42.9945],
#         [43.9945],
#         [45.4945],
#         [42.9945],
#         [43.9945],
#         [44.9945],
#         [44.9945],
#         [43.9945],
#         [42.9945],
#         [43.9945],
#         [43.9945],
#         [ 7.9945],
#         [40.9945],
#         [41.9945],
#         [40.9945],
#         [37.9945],
#         [37.9945],
#         [38.9945],
#         [38.9945],
#         [ 3.4945],
#         [37.9945],
#         [40.2445],
#         [41.2445],
#         [39.4945],
#         [38.4945],
#         [39.5570],
#         [ 5.7445],
#         [38.9945],
#         [39.2445],
#         [38.7445],
#         [36.9945],
#         [34.9945],
#         [34.2445],
#         [34.4945],
#         [35.2445],
#         [35.7445],
#         [35.8695],
#         [35.7445],
#         [36.2071],
#         [ 0.6321],
#         [ 0.9633],
#         [ 1.0258],
#         [ 0.9945],
#         [35.4320],
#         [35.1820],
#         [ 1.3070],
#         [36.0570],
#         [36.7445],
#         [37.7445],
#         [37.9945],
#         [37.2445],
#         [36.7445],
#         [36.9945],
#         [37.2445],
#         [ 3.4945],
#         [37.2445],
#         [35.7445],
#         [35.7445],
#         [35.9945],
#         [34.9945],
#         [35.9945],
#         [34.9945],
#         [34.9945],
#         [ 2.9945],
#         [ 3.6195],
#         [37.6195],
#         [38.4945],
#         [37.8695],
#         [37.7445],
#         [36.4945],
#         [36.4945],
#         [36.2445],
#         [35.2445],
#         [36.2445],
#         [37.2445],
#         [37.4945],
#         [36.4945],
#         [37.4945],
#         [37.7445],
#         [36.4945],
#         [37.2445],
#         [38.9945],
#         [42.9945],
#         [46.4945],
#         [46.9945],
#         [47.9945],
#         [47.9945],
#         [45.9945],
#         [45.9945],
#         [45.9945],
#         [46.9945],
#         [46.9945],
#         [47.9945],
#         [46.9945],
#         [47.9945],
#         [10.9945],
#         [49.9945],
#         [46.9945],
#         [12.9945],
#         [48.9945],
#         [44.9945],
#         [55.9945],
#         [43.9945],
#         [43.9945],
#         [39.9945],
#         [43.9945],
#         [47.9945],
#         [47.9945],
#         [49.9945],
#         [43.9945],
#         [47.9945],
#         [44.9945],
#         [47.9945],
#         [41.9945],
#         [43.9945],
#         [10.9945],
#         [47.9945],
#         [ 8.9945],
#         [45.9945],
#         [45.9945],
#         [48.9945],
#         [52.9945],
#         [51.9945],
#         [46.9945],
#         [52.9945],
#         [47.9945],
#         [45.9945],
#         [49.9945],
#         [55.9945],
#         [27.9945],
#         [51.9945],
#         [67.9945],
#         [55.9945],
#         [41.9945],
#         [59.9945],
#         [33.9945],
#         [53.9945],
#         [39.9945],
#         [67.9945],
#         [27.9945],
#         [59.9945],
#         [47.9945],
#         [47.9945],
#         [51.9945],
#         [47.9945],
#         [27.9945],
#         [ 7.9945],
#         [55.9945],
#         [71.9945],
#         [ 3.9945],
#         [15.9945],
#         [23.9945],
#         [27.9945],
#         [47.9945],
#         [57.9945],
#         [55.9945],
#         [49.9945],
#         [13.9945],
#         [53.9945],
#         [13.9945],
#         [17.9945],
#         [53.9945],
#         [61.9945],
#         [67.9945],
#         [39.9945],
#         [67.9945],
#         [55.9945],
#         [71.9945],
#         [39.9945],
#         [71.9945],
#         [51.9945],
#         [43.9945],
#         [67.9945],
#         [59.9945],
#         [39.9945],
#         [47.9945],
#         [35.9945],
#         [43.9945],
#         [47.9945],
#         [17.9945],
#         [47.9945],
#         [57.9945],
#         [51.9945],
#         [37.9945],
#         [15.9945],
#         [15.9945],
#         [55.9945],
#         [59.9945],
#         [-4.0055],
#         [ 9.9945],
#         [67.9945],
#         [51.9945],
#         [47.9945],
#         [49.9945],
#         [43.9945],
#         [47.9945],
#         [47.9945],
#         [47.9945],
#         [55.9945],
#         [15.9945],
#         [13.9945],
#         [45.9945],
#         [51.9945]], grad_fn=<AddmmBackward0>)
